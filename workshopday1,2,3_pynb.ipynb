# %%
4+5
# Out:
# 9

# %%
pwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-8e29cc1821a0> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     195     normed = _os.path.normpath(mountpoint)
#     196     if '/' in normed and not _os.path.exists(_os.path.dirname(normed)):
# --> 197       raise ValueError('Mountpoint must be in a directory that exists')
#     198   except:
#     199     d.kill(_signal.SIGKILL)
#
# ValueError: Mountpoint must be in a directory that exists

# %%
d ='coders ready'
len(d)
# Out:
# 12

# %%
import numpy as np
arr1 = np.array([[2,7,9],[5,8,6]])
arr1
# Out:
# array([[2, 7, 9],
#        [5, 8, 6]])

# %%
arr1.shape
# Out:
# (2, 3)

# %%
arr2 = np.random.randn(4,3)
arr2
# Out:
# array([[ 0.94571225, -0.23166744, -0.38201912],
#        [ 0.88136008, -0.55560869,  0.38739494],
#        [ 0.27276422,  0.9557329 ,  0.71931468],
#        [ 1.51156195, -1.47867547, -0.93232631]])

# %%
arr3 = np.random.randint(1,30, (4,3))
arr3
# Out:
# array([[ 4, 16, 13],
#        [24, 16, 18],
#        [14,  8, 21],
#        [10,  2,  5]])

# %%
import pandas as pd
df = pd.DataFrame(np.random.rand(5,5),index =['1' ,'2' ,'3' ,'4' ,'5'],columns = ['A' ,'B' ,'C' ,'D' ,'E'])
df
# Out:
#           A         B         C         D         E
# 1  0.817966  0.590330  0.501602  0.752055  0.506076
# 2  0.947614  0.474002  0.939003  0.300152  0.646858
# 3  0.748046  0.161631  0.276051  0.614562  0.694661
# 4  0.075308  0.212254  0.726212  0.382579  0.377179
# 5  0.907258  0.029587  0.250475  0.323201  0.527307

# %%
df.shape
# Out:
# (5, 5)

# %%
df.describe()
# Out:
#               A         B         C         D         E
# count  5.000000  5.000000  5.000000  5.000000  5.000000
# mean   0.699238  0.293561  0.538668  0.474510  0.550416
# std    0.357327  0.231478  0.295312  0.198992  0.125119
# min    0.075308  0.029587  0.250475  0.300152  0.377179
# 25%    0.748046  0.161631  0.276051  0.323201  0.506076
# 50%    0.817966  0.212254  0.501602  0.382579  0.527307
# 75%    0.907258  0.474002  0.726212  0.614562  0.646858
# max    0.947614  0.590330  0.939003  0.752055  0.694661

# %%
df['A']
# Out:
# 1    0.817966
# 2    0.947614
# 3    0.748046
# 4    0.075308
# 5    0.907258
# Name: A, dtype: float64

# %%
df.iloc[0]
# Out:
# A    0.817966
# B    0.590330
# C    0.501602
# D    0.752055
# E    0.506076
# Name: 1, dtype: float64

# %%
df.iloc[:,0:2]
# Out:
#           A         B
# 1  0.817966  0.590330
# 2  0.947614  0.474002
# 3  0.748046  0.161631
# 4  0.075308  0.212254
# 5  0.907258  0.029587

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,9))

N=500
t= np.linspace(0, 2*np.pi, N)

x = 5*np.cos(t) + 0.4 *np.random.normal(size=N) +1
y=4*np.sin(t)+0.4*np.random.normal(size =N)
plt.plot(x,y,('.k'))

plt.plot(0,0, 'or' ,markersize=15)
plt.plot (-3.6,-2, 'ob' ,markersize=15)

xmean,ymean = x.mean(), y.mean()
x -=xmean
y -=ymean

u,s,v =np.linalg.svd(np.stack((x,y)))

tt =np.linspace(0, 2*np.pi ,1000)
circle =np.stack((np.cos(tt), np.sin(tt)))

transform =np.sqrt(2/N) * u.dot(np.diag(s))

fit =transform.dot(circle) +np.array([[xmean],[ymean]])

plt.plot(fit[0,:],fit[1,:], '--b')
plt.title("Earth's orbotal walking path around sun fitted with eliptical Distribution")

plt.xlabel('ECIX')
plt.ylabel('ECIV')
plt.show()

# %%
# !pip install basemap
# !pip install basemap-data-hires
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: basemap in /usr/local/lib/python3.10/dist-packages (1.3.7)
# Requirement already satisfied: pyshp<2.4,>=1.2 in /usr/local/lib/python3.10/dist-packages (from basemap) (2.3.1)
# Requirement already satisfied: numpy<1.25,>=1.22 in /usr/local/lib/python3.10/dist-packages (from basemap) (1.22.4)
# Requirement already satisfied: pyproj<3.6.0,>=1.9.3 in /usr/local/lib/python3.10/dist-packages (from basemap) (3.5.0)
# Requirement already satisfied: basemap-data<1.4,>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from basemap) (1.3.2)
# Requirement already satisfied: matplotlib<3.8,>=1.5 in /usr/local/lib/python3.10/dist-packages (from basemap) (3.7.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (4.39.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj<3.6.0,>=1.9.3->basemap) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<3.8,>=1.5->basemap) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: basemap-data-hires in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install basemap
# !pip install basemap-data-hires
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting basemap
#   Downloading basemap-1.3.7-cp310-cp310-manylinux1_x86_64.whl (860 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 860.6/860.6 kB 35.4 MB/s eta 0:00:00
# Collecting basemap-data<1.4,>=1.3.2 (from basemap)
#   Downloading basemap_data-1.3.2-py2.py3-none-any.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 39.2 MB/s eta 0:00:00
# Collecting pyshp<2.4,>=1.2 (from basemap)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<3.8,>=1.5 in /usr/local/lib/python3.10/dist-packages (from basemap) (3.7.1)
# Collecting pyproj<3.6.0,>=1.9.3 (from basemap)
#   Downloading pyproj-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 85.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.25,>=1.22 in /usr/local/lib/python3.10/dist-packages (from basemap) (1.22.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<3.8,>=1.5->basemap) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from pyproj<3.6.0,>=1.9.3->basemap) (2022.12.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<3.8,>=1.5->basemap) (1.16.0)
# Installing collected packages: pyshp, pyproj, basemap-data, basemap
# Successfully installed basemap-1.3.7 basemap-data-1.3.2 pyproj-3.5.0 pyshp-2.3.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting basemap-data-hires
#   Downloading basemap_data_hires-1.3.2-py2.py3-none-any.whl (91.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 MB 9.7 MB/s eta 0:00:00
# Installing collected packages: basemap-data-hires
# Successfully installed basemap-data-hires-1.3.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
fig = plt.figure(figsize = (8,8), dpi=100)

m = Basemap(projection = 'lcc', resolution='h',
            width=7E6, height = 7E6,
            lat_0 = 21.4389, lon_0 = 87.0149)

m.etopo(scale=0.5, alpha = 0.5);

m.bluemarble(scale=0.5);

x, y = m(77.1025, 28.7041)
plt.plot(x,y, 'ok', markersize=5)
plt.text(x,y, 'Delhi', fontsize = 12)
x1, y1 = m(76.5979, 31.8996)
plt.plot(x1,y1, 'ok', markersize=5)
plt.text(x1,y1, 'Jaisinghpur', fontsize = 12)
# Out:
# Text(2500303.9945670892, 4703045.5246672025, 'Jaisinghpur')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# import pandas as pd
# import plotly.express as pr
# import plotly.graph_objects as go

# %%
df = pd.read_csv('/airline_data.csv.xls')
df
# Out:
#        Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0         1295781  1998        2      4           2          4  1998-04-02
# 1         1125375  2013        2      5          13          1  2013-05-13
# 2          118824  1993        3      9          25          6  1993-09-25
# 3          634825  1994        4     11          12          6  1994-11-12
# 4         1888125  2017        3      8          17          4  2017-08-17
# ...           ...   ...      ...    ...         ...        ...         ...
# 14390     1379850  2000        4     12          17          7  2000-12-17
# 14391     1182503  1991        1      3          16          6  1991-03-16
# 14392     1365760  2000        2      4           5          3  2000-04-05
# 14393     1427696  2011        2      5          11          3  2011-05-11
# 14394     1126033  1989        2      4          23          7  1989-04-23
#
#       Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 0                    AS                     19930                          AS
# 1                    EV                     20366                          EV
# 2                    UA                     19977                          UA
# 3                    HP                     19991                          HP
# 4                    UA                     19977                          UA
# ...                 ...                       ...                         ...
# 14390                UA                     19977                          UA
# 14391                AA                     19805                          AA
# 14392                TW                     20211                          TW
# 14393                WN                     19393                          WN
# 14394                US                     20355                          US
#
#        ... Div4WheelsOff  Div4TailNum  Div5Airport  Div5AirportID  \
# 0      ...           NaN          NaN          NaN            NaN
# 1      ...           NaN          NaN          NaN            NaN
# 2      ...           NaN          NaN          NaN            NaN
# 3      ...           NaN          NaN          NaN            NaN
# 4      ...           NaN          NaN          NaN            NaN
# ...    ...           ...          ...          ...            ...
# 14390  ...           NaN          NaN          NaN            NaN
# 14391  ...           NaN          NaN          NaN            NaN
# 14392  ...           NaN          NaN          NaN            NaN
# 14393  ...           NaN          NaN          NaN            NaN
# 14394  ...           NaN          NaN          NaN            NaN
#
#        Div5AirportSeqID Div5WheelsOn Div5TotalGTime Div5LongestGTime  \
# 0                   NaN          NaN            NaN              NaN
# 1                   NaN          NaN            NaN              NaN
# 2                   NaN          NaN            NaN              NaN
# 3                   NaN          NaN            NaN              NaN
# 4                   NaN          NaN            NaN              NaN
# ...                 ...          ...            ...              ...
# 14390               NaN          NaN            NaN              NaN
# 14391               NaN          NaN            NaN              NaN
# 14392               NaN          NaN            NaN              NaN
# 14393               NaN          NaN            NaN              NaN
# 14394               NaN          NaN            NaN              NaN
#
#        Div5WheelsOff Div5TailNum
# 0                NaN         NaN
# 1                NaN         NaN
# 2                NaN         NaN
# 3                NaN         NaN
# 4                NaN         NaN
# ...              ...         ...
# 14390            NaN         NaN
# 14391            NaN         NaN
# 14392            NaN         NaN
# 14393            NaN         NaN
# 14394            NaN         NaN
#
# [14395 rows x 110 columns]

# %%
df1=df.copy()
df1
# Out:
#        Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0         1295781  1998        2      4           2          4  1998-04-02
# 1         1125375  2013        2      5          13          1  2013-05-13
# 2          118824  1993        3      9          25          6  1993-09-25
# 3          634825  1994        4     11          12          6  1994-11-12
# 4         1888125  2017        3      8          17          4  2017-08-17
# ...           ...   ...      ...    ...         ...        ...         ...
# 14390     1379850  2000        4     12          17          7  2000-12-17
# 14391     1182503  1991        1      3          16          6  1991-03-16
# 14392     1365760  2000        2      4           5          3  2000-04-05
# 14393     1427696  2011        2      5          11          3  2011-05-11
# 14394     1126033  1989        2      4          23          7  1989-04-23
#
#       Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 0                    AS                     19930                          AS
# 1                    EV                     20366                          EV
# 2                    UA                     19977                          UA
# 3                    HP                     19991                          HP
# 4                    UA                     19977                          UA
# ...                 ...                       ...                         ...
# 14390                UA                     19977                          UA
# 14391                AA                     19805                          AA
# 14392                TW                     20211                          TW
# 14393                WN                     19393                          WN
# 14394                US                     20355                          US
#
#        ... Div4WheelsOff  Div4TailNum  Div5Airport  Div5AirportID  \
# 0      ...           NaN          NaN          NaN            NaN
# 1      ...           NaN          NaN          NaN            NaN
# 2      ...           NaN          NaN          NaN            NaN
# 3      ...           NaN          NaN          NaN            NaN
# 4      ...           NaN          NaN          NaN            NaN
# ...    ...           ...          ...          ...            ...
# 14390  ...           NaN          NaN          NaN            NaN
# 14391  ...           NaN          NaN          NaN            NaN
# 14392  ...           NaN          NaN          NaN            NaN
# 14393  ...           NaN          NaN          NaN            NaN
# 14394  ...           NaN          NaN          NaN            NaN
#
#        Div5AirportSeqID Div5WheelsOn Div5TotalGTime Div5LongestGTime  \
# 0                   NaN          NaN            NaN              NaN
# 1                   NaN          NaN            NaN              NaN
# 2                   NaN          NaN            NaN              NaN
# 3                   NaN          NaN            NaN              NaN
# 4                   NaN          NaN            NaN              NaN
# ...                 ...          ...            ...              ...
# 14390               NaN          NaN            NaN              NaN
# 14391               NaN          NaN            NaN              NaN
# 14392               NaN          NaN            NaN              NaN
# 14393               NaN          NaN            NaN              NaN
# 14394               NaN          NaN            NaN              NaN
#
#        Div5WheelsOff Div5TailNum
# 0                NaN         NaN
# 1                NaN         NaN
# 2                NaN         NaN
# 3                NaN         NaN
# 4                NaN         NaN
# ...              ...         ...
# 14390            NaN         NaN
# 14391            NaN         NaN
# 14392            NaN         NaN
# 14393            NaN         NaN
# 14394            NaN         NaN
#
# [14395 rows x 110 columns]

# %%
df.shape
# Out:
# (14395, 110)

# %%
df .columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'FlightDate', 'Reporting_Airline', 'DOT_ID_Reporting_Airline',
#        'IATA_CODE_Reporting_Airline',
#        ...
#        'Div4WheelsOff', 'Div4TailNum', 'Div5Airport', 'Div5AirportID',
#        'Div5AirportSeqID', 'Div5WheelsOn', 'Div5TotalGTime',
#        'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum'],
#       dtype='object', length=110)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14395 entries, 0 to 14394
# Columns: 110 entries, Unnamed: 0 to Div5TailNum
# dtypes: float64(82), int64(11), object(17)
# memory usage: 12.1+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0          Year       Quarter         Month    DayofMonth  \
# count  1.439500e+04  14395.000000  14395.000000  14395.000000  14395.000000
# mean   9.981857e+05   2004.374852      2.520250      6.553734     15.686905
# std    5.756890e+05      9.155638      1.116304      3.453790      8.833742
# min    1.480000e+02   1987.000000      1.000000      1.000000      1.000000
# 25%    5.046040e+05   1997.000000      2.000000      4.000000      8.000000
# 50%    9.994150e+05   2005.000000      3.000000      7.000000     16.000000
# 75%    1.495611e+06   2012.000000      4.000000     10.000000     23.000000
# max    1.999844e+06   2020.000000      4.000000     12.000000     31.000000
#
#           DayOfWeek  DOT_ID_Reporting_Airline  \
# count  14395.000000              14395.000000
# mean       3.930045              19924.572074
# std        1.993608                368.767340
# min        1.000000              19386.000000
# 25%        2.000000              19704.000000
# 50%        4.000000              19805.000000
# 75%        6.000000              20355.000000
# max        7.000000              21171.000000
#
#        Flight_Number_Reporting_Airline  OriginAirportID  OriginAirportSeqID  \
# count                     14395.000000     14395.000000        1.439500e+04
# mean                       1741.754706     12727.241264        1.272726e+06
# std                        1656.648657      1543.513860        1.543512e+05
# min                           1.000000     10135.000000        1.013501e+06
# 25%                         532.500000     11292.000000        1.129202e+06
# 50%                        1189.000000     12892.000000        1.289201e+06
# 75%                        2259.000000     14100.000000        1.410001e+06
# max                        7934.000000     16440.000000        1.644001e+06
#
#        ...  Div4WheelsOff  Div4TailNum  Div5Airport  Div5AirportID  \
# count  ...            0.0          0.0          0.0            0.0
# mean   ...            NaN          NaN          NaN            NaN
# std    ...            NaN          NaN          NaN            NaN
# min    ...            NaN          NaN          NaN            NaN
# 25%    ...            NaN          NaN          NaN            NaN
# 50%    ...            NaN          NaN          NaN            NaN
# 75%    ...            NaN          NaN          NaN            NaN
# max    ...            NaN          NaN          NaN            NaN
#
#        Div5AirportSeqID  Div5WheelsOn  Div5TotalGTime  Div5LongestGTime  \
# count               0.0           0.0             0.0               0.0
# mean                NaN           NaN             NaN               NaN
# std                 NaN           NaN             NaN               NaN
# min                 NaN           NaN             NaN               NaN
# 25%                 NaN           NaN             NaN               NaN
# 50%                 NaN           NaN             NaN               NaN
# 75%                 NaN           NaN             NaN               NaN
# max                 NaN           NaN             NaN               NaN
#
#        Div5WheelsOff  Div5TailNum
# count            0.0          0.0
# mean             NaN          NaN
# std              NaN          NaN
# min              NaN          NaN
# 25%              NaN          NaN
# 50%              NaN          NaN
# 75%              NaN          NaN
# max              NaN          NaN
#
# [8 rows x 93 columns]

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14390    False
# 14391    False
# 14392    False
# 14393    False
# 14394    False
# Length: 14395, dtype: bool

# %%
df.isna()
# Out:
#        Unnamed: 0   Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0           False  False    False  False       False      False       False
# 1           False  False    False  False       False      False       False
# 2           False  False    False  False       False      False       False
# 3           False  False    False  False       False      False       False
# 4           False  False    False  False       False      False       False
# ...           ...    ...      ...    ...         ...        ...         ...
# 14390       False  False    False  False       False      False       False
# 14391       False  False    False  False       False      False       False
# 14392       False  False    False  False       False      False       False
# 14393       False  False    False  False       False      False       False
# 14394       False  False    False  False       False      False       False
#
#        Reporting_Airline  DOT_ID_Reporting_Airline  \
# 0                  False                     False
# 1                  False                     False
# 2                  False                     False
# 3                  False                     False
# 4                  False                     False
# ...                  ...                       ...
# 14390              False                     False
# 14391              False                     False
# 14392              False                     False
# 14393              False                     False
# 14394              False                     False
#
#        IATA_CODE_Reporting_Airline  ...  Div4WheelsOff  Div4TailNum  \
# 0                            False  ...           True         True
# 1                            False  ...           True         True
# 2                            False  ...           True         True
# 3                            False  ...           True         True
# 4                            False  ...           True         True
# ...                            ...  ...            ...          ...
# 14390                        False  ...           True         True
# 14391                        False  ...           True         True
# 14392                        False  ...           True         True
# 14393                        False  ...           True         True
# 14394                        False  ...           True         True
#
#        Div5Airport  Div5AirportID  Div5AirportSeqID  Div5WheelsOn  \
# 0             True           True              True          True
# 1             True           True              True          True
# 2             True           True              True          True
# 3             True           True              True          True
# 4             True           True              True          True
# ...            ...            ...               ...           ...
# 14390         True           True              True          True
# 14391         True           True              True          True
# 14392         True           True              True          True
# 14393         True           True              True          True
# 14394         True           True              True          True
#
#        Div5TotalGTime  Div5LongestGTime  Div5WheelsOff  Div5TailNum
# 0                True              True           True         True
# 1                True              True           True         True
# 2                True              True           True         True
# 3                True              True           True         True
# 4                True              True           True         True
# ...               ...               ...            ...          ...
# 14390            True              True           True         True
# 14391            True              True           True         True
# 14392            True              True           True         True
# 14393            True              True           True         True
# 14394            True              True           True         True
#
# [14395 rows x 110 columns]

# %%
df.isna().sum()
# Out:
# Unnamed: 0              0
# Year                    0
# Quarter                 0
# Month                   0
# DayofMonth              0
#                     ...
# Div5WheelsOn        14395
# Div5TotalGTime      14395
# Div5LongestGTime    14395
# Div5WheelsOff       14395
# Div5TailNum         14395
# Length: 110, dtype: int64

# %%
df.dropna(axis = 1,inplace =True)
df.dtypes
# Out:
# Unnamed: 0                          int64
# Year                                int64
# Quarter                             int64
# Month                               int64
# DayofMonth                          int64
# DayOfWeek                           int64
# FlightDate                         object
# Reporting_Airline                  object
# DOT_ID_Reporting_Airline            int64
# IATA_CODE_Reporting_Airline        object
# Flight_Number_Reporting_Airline     int64
# OriginAirportID                     int64
# OriginAirportSeqID                  int64
# OriginCityMarketID                  int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27000 entries, 0 to 26999
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       27000 non-null  int64
#  1   Year                             27000 non-null  int64
#  2   Quarter                          27000 non-null  int64
#  3   Month                            27000 non-null  int64
#  4   DayofMonth                       27000 non-null  int64
#  5   DayOfWeek                        27000 non-null  int64
#  6   FlightDate                       27000 non-null  object
#  7   Reporting_Airline                27000 non-null  object
#  8   DOT_ID_Reporting_Airline         27000 non-null  int64
#  9   IATA_CODE_Reporting_Airline      27000 non-null  object
#  10  Flight_Number_Reporting_Airline  27000 non-null  int64
#  11  OriginAirportID                  27000 non-null  int64
#  12  OriginAirportSeqID               27000 non-null  int64
#  13  OriginCityMarketID               27000 non-null  int64
#  14  Origin                           27000 non-null  object
#  15  OriginCityName                   27000 non-null  object
#  16  OriginWac                        27000 non-null  int64
#  17  DestAirportID                    27000 non-null  int64
#  18  DestAirportSeqID                 27000 non-null  int64
#  19  DestCityMarketID                 27000 non-null  int64
#  20  Dest                             27000 non-null  object
#  21  DestCityName                     27000 non-null  object
#  22  DestWac                          27000 non-null  int64
#  23  CRSDepTime                       27000 non-null  int64
#  24  DepTimeBlk                       27000 non-null  object
#  25  CRSArrTime                       27000 non-null  int64
#  26  ArrTimeBlk                       27000 non-null  object
#  27  Cancelled                        27000 non-null  float64
#  28  Diverted                         27000 non-null  float64
#  29  Flights                          27000 non-null  float64
#  30  Distance                         27000 non-null  float64
#  31  DistanceGroup                    27000 non-null  int64
# dtypes: float64(4), int64(19), object(9)
# memory usage: 6.6+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14395 entries, 0 to 14394
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       14395 non-null  int64
#  1   Year                             14395 non-null  int64
#  2   Quarter                          14395 non-null  int64
#  3   Month                            14395 non-null  int64
#  4   DayofMonth                       14395 non-null  int64
#  5   DayOfWeek                        14395 non-null  int64
#  6   FlightDate                       14395 non-null  object
#  7   Reporting_Airline                14395 non-null  object
#  8   DOT_ID_Reporting_Airline         14395 non-null  int64
#  9   IATA_CODE_Reporting_Airline      14395 non-null  object
#  10  Flight_Number_Reporting_Airline  14395 non-null  int64
#  11  OriginAirportID                  14395 non-null  int64
#  12  OriginAirportSeqID               14395 non-null  int64
#  13  OriginCityMarketID               14395 non-null  int64
# dtypes: int64(11), object(3)
# memory usage: 1.5+ MB

# %%
df.count()
# Out:
# Unnamed: 0                         14395
# Year                               14395
# Quarter                            14395
# Month                              14395
# DayofMonth                         14395
# DayOfWeek                          14395
# FlightDate                         14395
# Reporting_Airline                  14395
# DOT_ID_Reporting_Airline           14395
# IATA_CODE_Reporting_Airline        14395
# Flight_Number_Reporting_Airline    14395
# OriginAirportID                    14395
# OriginAirportSeqID                 14395
# OriginCityMarketID                 14395
# dtype: int64

# %%
df = df.drop(['Unnamed: 0'], axis =1)

# %%
line_data = df .groupby('Month')['ArrDelay'].mean().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-5483c147dee7> in <cell line: 1>()
# ----> 1 line_data = df .groupby('Month')['ArrDelay'].mean().reset_index()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1414                 stacklevel=find_stack_level(),
#    1415             )
# -> 1416         return super().__getitem__(key)
#    1417
#    1418     def _gotitem(self, key, ndim: int, subset=None):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in __getitem__(self, key)
#     246         else:
#     247             if key not in self.obj:
# --> 248                 raise KeyError(f"Column not found: {key}")
#     249             subset = self.obj[key]
#     250             ndim = subset.ndim
#
# KeyError: 'Column not found: ArrDelay'

# %%
line_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-aece71516710> in <cell line: 1>()
# ----> 1 line_data
#
# NameError: name 'line_data' is not defined

# %%
fig = go .Figure(data=go.Scatter(x=line_data['Month'],y=line_data['ArrDelay'], mode='lines', marker=dict(color="green"))) 

fig.update_layout(title='monthly average delay of flights',xaxis)
# Out:
#   File "<ipython-input-28-4f11f0e8ccf4>", line 3
#     fig.update_layout(title='monthly average delay of flights',xaxis)
#                                                                     ^
# SyntaxError: positional argument follows keyword argument

# %%
import matplotlib.pyplib.pyplot as plt

plt.figure(figsize=(8, 6), dpi=90)

fig = pr.pie(df,names='distanceGroup',title='Monthly Distance_group proportion travelled')
plt.savefig("123.jpg")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-69-d5f9f0d7a88a> in <cell line: 1>()
# ----> 1 import matplotlib.pyplib.pyplot as plt
#       2
#       3 plt.figure(figsize=(8, 6), dpi=90)
#       4
#       5 fig = pr.pie(df,names='distanceGroup',title='Monthly Distance_group proportion travelled')
#
# ModuleNotFoundError: No module named 'matplotlib.pyplib'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
